# %%
import pandas as pd
from textblob import TextBlob

# %%
xls = pd.ExcelFile('Comments on the survey-2.xlsx')
df1 = pd.read_excel(xls, 'Open Comments')

# %%
df1
# Out:
#           Decisions                              Actions  \
# 0    Lower priority                            Make this
# 1         Easy fix.                                 Done
# 2             Check                                 Done
# 3          Easy fix                                 Done
# 4         Easy fix.                                 Done
# ..              ...                                  ...
# 139             NaN                                Noted
# 140             NaN                             Actioned
# 141             NaN                             Actioned
# 142             NaN  I'll add a note in the main survey.
# 143             NaN                                  NaN
#
#                                            Dan's Notes  \
# 0                                                  NaN
# 1               Fully describe what "acceptable" means
# 2                                                  NaN
# 3                                                  NaN
# 4                                     It's characters!
# ..                                                 ...
# 139                             Good shout, thank you.
# 140                                         Thank you.
# 141  People are split on this. I'll seperate this out.
# 142  Because there is a seperate survey specificall...
# 143                                                NaN
#
#                                          Open Comments          Who  \
# 0    Create a photo sheet that gives visual example...          Dan
# 1    Acceptable and unacceptable walking on roads a...            J
# 2    Accessibility grade – Remove – with the except...            J
# 3    Climbing over fences and walls  - similar to a...            J
# 4    Describe the route - a  maximum word limit of ...            J
# ..                                                 ...          ...
# 139  gpx filetype not recognised. See it's agreed t...  John Milroy
# 140  The livestock questions are still problematic ...          NaN
# 141  Why say livestock when it's only really cows a...          NaN
# 142  The facilities question is still unclear.  It ...          NaN
# 143  Just a thought,There are many walking groups a...  Eric Forgan
#
#                                   Comments on comments  \
# 0                                                  NaN
# 1    Andrew M - Agree (I think this could be includ...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
#
#                                      Slow Ways Actions
# 0                                                  NaN
# 1                                                  NaN
# 2    Potentially rename the grade (to restrictions ...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
#
# [144 rows x 7 columns]

# %%
df1 = df1[['Open Comments', 'Decisions', 'Actions']]

# %%
df1.head(20)
# Out:
#                                         Open Comments       Decisions  \
# 0   Create a photo sheet that gives visual example...  Lower priority
# 1   Acceptable and unacceptable walking on roads a...       Easy fix.
# 2   Accessibility grade – Remove – with the except...           Check
# 3   Climbing over fences and walls  - similar to a...        Easy fix
# 4   Describe the route - a  maximum word limit of ...       Easy fix.
# 5   Dog friendly route  - probably needs an explan...       Easy fix.
# 6   Gates -  there are lots of different types of ...            Hard
# 7   High likehood of horses & cattle  -  is livest...        Easy fix
# 8   In Scotland  you can walk along the edge of a ...        Easy fix
# 9   Number of obstacles - Steps  - is total number...           Noted
# 10  Obstacles and features  - Do you want to inclu...        Easy fix
# 11  Path Surface grade – to avoid confusion with t...        Easy fix
# 12  Right of access unknown  -  this isn’t applica...           Noted
# 13  Sections of  long grass or crops  - should you...        Easy fix
# 14  What’s the narrowest part of the path? – sugge...        Easy fix
# 15  What about an app for keeping tally of things ...  Lower priority
# 16  Contact off-road mobility scooter people to se...          Action
# 17  Ask a visually impaired walking group for thei...          Action
# 18  Can you make the seasonability of the survey c...        Easy fix
# 19  Accessability grade - Is waymarking along the ...        Easy fix
#
#              Actions
# 0          Make this
# 1               Done
# 2               Done
# 3               Done
# 4               Done
# 5               Done
# 6            Delayed
# 7               Done
# 8                NaN
# 9            Delayed
# 10              Done
# 11              Done
# 12             Noted
# 13         Addressed
# 14              Done
# 15               NaN
# 16  For next version
# 17  For next version
# 18              Done
# 19              Done

# %%
Comment = TextBlob(df1.at[4, 'Open Comments'])

# %%
Comment.sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.5)

# %%
Comment = TextBlob(df1.at[5, 'Open Comments'])

# %%
Comment.sentiment
# Out:
# Sentiment(polarity=0.375, subjectivity=0.5)

# %%
Comment = TextBlob('this is amazing')
Comment.sentiment
# Out:
# Sentiment(polarity=0.6000000000000001, subjectivity=0.9)

# %%
def sentiment(text):
    try:
        return TextBlob(text).sentiment
    except:
        return None

# %%
df1['polarity'] = df1['Open Comments'].apply(sentiment).apply(lambda x:x[0])
# Out:
# <ipython-input-16-16053a5a2840>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['polarity'] = df1['Open Comments'].apply(sentiment).apply(lambda x:x[0])

# %%
df1.head()
# Out:
#                                        Open Comments       Decisions  \
# 0  Create a photo sheet that gives visual example...  Lower priority
# 1  Acceptable and unacceptable walking on roads a...       Easy fix.
# 2  Accessibility grade – Remove – with the except...           Check
# 3  Climbing over fences and walls  - similar to a...        Easy fix
# 4  Describe the route - a  maximum word limit of ...       Easy fix.
#
#      Actions  polarity
# 0  Make this  0.000000
# 1       Done -0.150000
# 2       Done  0.075000
# 3       Done  0.166667
# 4       Done  0.000000
